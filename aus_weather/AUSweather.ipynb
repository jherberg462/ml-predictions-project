# %%
import numpy as np
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %%
#Set File Paths for weather Data CSV Files
weatherAUS = "../final_project/weatherAUS.csv"

# %%
#Import weather CSV to Pandas Data Frame
weather = pd.read_csv(weatherAUS)

#Display Data Frame
weather
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# 5       2008-12-06   Albury     14.6     29.7       0.2          NaN
# 6       2008-12-07   Albury     14.3     25.0       0.0          NaN
# 7       2008-12-08   Albury      7.7     26.7       0.0          NaN
# 8       2008-12-09   Albury      9.7     31.9       0.0          NaN
# 9       2008-12-10   Albury     13.1     30.1       1.4          NaN
# 10      2008-12-11   Albury     13.4     30.4       0.0          NaN
# 11      2008-12-12   Albury     15.9     21.7       2.2          NaN
# 12      2008-12-13   Albury     15.9     18.6      15.6          NaN
# ...

# %%
#display the names of all the unique locations for weather data
locations = weather['Location'].unique()
locations
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
#number of total locations
location_counter = weather['Location'].nunique()
location_counter
# Out:
# 49

# %%
#split each unique location into its own dataframe
location_grouped = weather.groupby(['Location'])
melbourne_weather = location_grouped.get_group("Melbourne")
melbourne_weather = melbourne_weather.reset_index(drop=True)

#if we would like weather can be further analyzed for Melbourne
melbourne_weather
# Out:
#             Date   Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0     2008-07-01  Melbourne      9.5     15.4       2.0          2.8
# 1     2008-07-02  Melbourne     11.0     14.5       0.6          5.2
# 2     2008-07-03  Melbourne      8.4     14.1       1.4          2.0
# 3     2008-07-04  Melbourne      9.1     14.5       0.6          1.8
# 4     2008-07-05  Melbourne      4.3     15.5       0.0          0.8
# 5     2008-07-06  Melbourne      5.5     15.4       0.0          2.8
# 6     2008-07-07  Melbourne     11.5     14.3       0.0          3.0
# 7     2008-07-08  Melbourne      6.9     10.4       5.0          1.2
# 8     2008-07-09  Melbourne      3.6     14.8       1.2          0.4
# 9     2008-07-10  Melbourne      4.2     13.5       3.0          2.2
# 10    2008-07-11  Melbourne      7.4     13.5       0.2          1.8
# 11    2008-07-12  Melbourne      6.6     11.3       0.0          2.0
# 12    2008-07-13  Melbourne      8.4     14.3       0.0          3.8
# ...
